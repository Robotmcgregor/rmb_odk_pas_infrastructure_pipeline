# %% [markdown]
# # ODK Mapping pipeline.
#
# Copyright 2021 Robert McGregor

# %% [markdown]
# This notebook controls the processing of odk mapping results and produces the following shapefiles (output GDA94):
# - infrastructure line shapefiles
# - infrastructure point shapefiles
# - infrasturcutre water point shapefiles
# - weeds record shapefiles - ready for WMB data upload
# - general POI mapping shapefiles.

# %% [markdown]
# ### cd to the directory from the Anaconda/Miniconda terminal.
#
# cd E:\DENR\code\rangeland_monitoring\rmb_mapping

# %% [markdown]
# #### Change your working directory to code

# %%
import os
path_parent = os.path.dirname(os.getcwd())
code_dir =  path_parent +  '\\code'
os.chdir(code_dir)
print(os.getcwd())
# Out:
# E:\DENR\code\rangeland_monitoring\rmb_mapping_pipeline\code

# %%
# %run step1_1_initiate_mapping_pipeline.py -h
# Out:
# usage: step1_1_initiate_mapping_pipeline.py [-h] [-d DIRECTORY_ODK]
#                                             [-x EXPORT_DIR]
#                                             [-pd PASTORAL_DISTRICTS_DIRECTORY]
#                                             [-ver VERSION] [-r REMOTE_DESKTOP]
#                                             [-t TIME_SLEEP] [-c CHROME_DRIVER]
#                                             [-s START_DATE] [-e END_DATE]
#                                             [-w WEEDS_LIST]
#                                             [-pe PROPERTY_ENQUIRE]
#                                             [-i INFRASTRUCTURE_DIRECTORY]
#                                             [-td TRANSITION_DIR]
#                                             [-a ASSETS_DIR]
#
# Process raw RMB Mapping result csv -> csv, shapefiles.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -d DIRECTORY_ODK, --directory_odk DIRECTORY_ODK
#                         The directory containing ODK csv files.
#   -x EXPORT_DIR, --export_dir EXPORT_DIR
#                         Directory path for outputs.
#   -pd PASTORAL_DISTRICTS_DIRECTORY, --pastoral_districts_directory PASTORAL_DISTRICTS_DIRECTORY
#                         Enter path to the Pastoral_Districts directory in the
#                         Spatial\Working drive)
#   -ver VERSION, --version VERSION
#                         Enter odk form version (i.e. v1 or v2.
#   -r REMOTE_DESKTOP, --remote_desktop REMOTE_DESKTOP
#                         Working on the remote_desktop? - Enter remote_auto,
#                         remote, local or offline.
#   -t TIME_SLEEP, --time_sleep TIME_SLEEP
#                         Time between odk aggregate actions -if lagging
#                         increase integer
#   -c CHROME_DRIVER, --chrome_driver CHROME_DRIVER
#                         File path for the chrome extension driver.
#   -s START_DATE, --start_date START_DATE
#                         Filter results by start date.
#   -e END_DATE, --end_date END_DATE
#                         Filter results by end date.
#   -w WEEDS_LIST, --weeds_list WEEDS_LIST
#                         Path to the weeds_list.csv.
#   -pe PROPERTY_ENQUIRE, --property_enquire PROPERTY_ENQUIRE
#                         Single property name to process - otherwise all
#                         properties will be processed (i.e. 'ROCKHAMPTON
#                         DOWNS').
#   -i INFRASTRUCTURE_DIRECTORY, --infrastructure_directory INFRASTRUCTURE_DIRECTORY
#                         The pastoral infrastructure directory (corporate
#                         drive).
#   -td TRANSITION_DIR, --transition_dir TRANSITION_DIR
#                         Directory path for outputs.
#   -a ASSETS_DIR, --assets_dir ASSETS_DIR
#                         Directory path containing required shapefile
#                         structure.

# %%
# %run step1_1_initiate_mapping_pipeline.py -x Z:\Scratch\Zonal_Stats_Pipeline\rmb_mapping\outputs -r remote_auto
# Out:
# The following data filters have been applied:
#  - Start date: 2021-01-01
#  - End date:  2021-10-31
#  - Property name:  All
# The following files were located in your download folder:  []
# You have selected Remote Auto, python now has control of your computer, step back and enjoy the ride.
# RMB_Mapping_v1_results.csv have been moved to  E:\DENR\code\rangeland_monitoring\rmb_mapping_pipeline\raw_odk
# ==================================================
# Searching for:  RMB_Mapping_v1_results.csv
# RMB_Mapping_v1_results.csv  located!!
# ==================================================
# prop name identified:  AMUNGEE MUNGEE
# ==================================================
# prop name identified:  ANNINGIE
# ==================================================
# prop name identified:  ANNITOWA
# ==================================================
# prop name identified:  BIRRINDUDU
# ==================================================
# prop name identified:  BOND SPRINGS
# ==================================================
# prop name identified:  BUNDA
# ==================================================
# prop name identified:  CONISTON
# ==================================================
# prop name identified:  CRESSWELL DOWNS
# ==================================================
# prop name identified:  CURTIN SPRINGS
# ==================================================
# prop name identified:  ELKEDRA
# ==================================================
# prop name identified:  GOONDOOLOO
# ==================================================
# prop name identified:  GREENBANK
# ==================================================
# prop name identified:  HIDDEN VALLEY
# ==================================================
# prop name identified:  HORSESHOE BEND
# ==================================================
# prop name identified:  KALALA
# ==================================================
# prop name identified:  KIRKIMBIE
# ==================================================
# prop name identified:  LABELLE DOWNS
# ==================================================
# prop name identified:  LEGUNE
# ==================================================
# prop name identified:  LIMBUNYA
# ==================================================
# prop name identified:  MARRAKAI
# ==================================================
# prop name identified:  MARYFIELD
# ==================================================
# prop name identified:  MCKINLAY RIVER
# ==================================================
# prop name identified:  MOROAK
# ==================================================
# prop name identified:  MOUNT DOREEN
# ==================================================
# prop name identified:  MOUNT EBENEZER
# ==================================================
# prop name identified:  MOUNT KEPPLER
# ==================================================
# prop name identified:  MOUNT RIDDOCK
# ==================================================
# prop name identified:  MOUNT SKINNER
# ==================================================
# prop name identified:  MOUNTAIN VALLEY
# ==================================================
# prop name identified:  MURRANJI
# ==================================================
# prop name identified:  NAPPERBY
# ==================================================
# prop name identified:  NARWIETOOMA
# ==================================================
# prop name identified:  NEWRY
# ==================================================
# prop name identified:  OLD MOUNT BUNDEY
# ==================================================
# prop name identified:  OORATIPPRA
# ==================================================
# prop name identified:  PUNGALINA
# ==================================================
# prop name identified:  RIVEREN
# ==================================================
# prop name identified:  ROCKHAMPTON DOWNS
# ==================================================
# prop name identified:  ROSEWOOD
# ==================================================
# prop name identified:  SEVEN EMU
# ==================================================
# prop name identified:  SINGLETON
# ==================================================
# prop name identified:  SPIRIT HILLS
# ==================================================
# prop name identified:  SPRING CREEK
# ==================================================
# prop name identified:  STIRLING
# ==================================================
# prop name identified:  THE GARDEN
# ==================================================
# prop name identified:  TOBERMOREY
# ==================================================
# prop name identified:  WALHALLOW
# ==================================================
# prop name identified:  WALLAMUNGA
# ==================================================
# prop name identified:  WELLTREE
# ==================================================
# prop name identified:  WOODGREEN
# ==================================================
# prop name identified:  WOOLNER
# ==================================================
# ==================================================
# property name to be processed:  AMUNGEE MUNGEE
#  - point feature:  infra_points
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  woody_thickening
#  - point feature:  feral_animals
# ==================================================
# property name to be processed:  ANNINGIE
#  - point feature:  erosion
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  ANNITOWA
#  - point feature:  infra_water_points
# ==================================================
# property name to be processed:  BIRRINDUDU
#  - point feature:  infra_points
#  - point feature:  infra_water_points
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  woody_thickening
#  - point feature:  feral_animals
# ==================================================
# property name to be processed:  BOND SPRINGS
#  - point feature:  infra_water_points
#  - point feature:  erosion
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  BUNDA
#  - point feature:  infra_points
#  - point feature:  infra_water_points
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  feral_animals
#  - point feature:  other_feature
# ==================================================
# property name to be processed:
Cultural Lines  Fenceline  Not Recorded
#
#                  district       property prop_code    date_rec  date_curr  \
# 0  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 1  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 2  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 3  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 4  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 5  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 2  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 3  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 4  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 5  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat         lon    acc  dist  bear
# 0 -22.967370  134.835307  4.551   NaN   NaN
# 1 -22.967448  134.838268  4.551   0.0   0.0
# 2 -22.967483  134.842752  4.551   0.0   0.0
# 3 -22.967704  134.850848  4.551   0.0   0.0
# 4 -22.967778  134.854463  4.551   0.0   0.0
# 5 -22.967804  134.857490  4.551   0.0   0.0  ,    uid_feature   feature_group    feature         label  \
# 0            7  Cultural Lines  Fenceline  Not Recorded
# 1            7  Cultural Lines  Fenceline  Not Recorded
# 2            7  Cultural Lines  Fenceline  Not Recorded
# 3            7  Cultural Lines  Fenceline  Not Recorded
# 4            7  Cultural Lines  Fenceline  Not Recorded
# 5            7  Cultural Lines  Fenceline  Not Recorded
#
#                  district       property prop_code    date_rec  date_curr  \
# 0  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 1  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 2  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 3  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 4  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 5  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 2  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 3  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 4  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 5  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat         lon    acc  dist  bear
# 0 -22.967811  134.857949  4.551   NaN   NaN
# 1 -22.967321  134.861595  4.551   0.0   0.0
# 2 -22.966349  134.868784  4.551   0.0   0.0
# 3 -22.965705  134.873590  4.551   0.0   0.0
# 4 -22.963862  134.887415  4.551   0.0   0.0
# 5 -22.964148  134.888710  4.551   0.0   0.0  ,    uid_feature   feature_group    feature         label  \
# 0            8  Cultural Lines  Fenceline  Not Recorded
# 1            8  Cultural Lines  Fenceline  Not Recorded
# 2            8  Cultural Lines  Fenceline  Not Recorded
# 3            8  Cultural Lines  Fenceline  Not Recorded
#
#                  district       property prop_code    date_rec  date_curr  \
# 0  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 1  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 2  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
# 3  Northern Alice Springs  MOUNT RIDDOCK       MRK  2021-08-11        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 2  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 3  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat         lon    acc  dist  bear
# 0 -22.963291  134.890446  4.551   NaN   NaN
# 1 -22.962263  134.894788  4.551   0.0   0.0
# 2 -22.960647  134.901606  4.551   0.0   0.0
# 3 -22.958454  134.911057  4.551   0.0   0.0  ]
#  - point feature:  infra_points
#  - point feature:  infra_water_points
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  MOUNT SKINNER
# df_list:  [   uid_feature   feature_group    feature         label  \
# 0            1  Cultural Lines  Fenceline  Not Recorded
# 1            1  Cultural Lines  Fenceline  Not Recorded
#
#                  district       property prop_code    date_rec  date_curr  \
# 0  Northern Alice Springs  MOUNT SKINNER       MSK  2021-07-21        NaN
# 1  Northern Alice Springs  MOUNT SKINNER       MSK  2021-07-21        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat        lon    acc  dist  bear
# 0 -22.280088  134.30091  4.551   NaN   NaN
# 1 -22.278414  134.30036  4.854   0.0   0.0  ]
#  - point feature:  infra_points
#  - point feature:  infra_water_points
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  MOUNTAIN VALLEY
# df_list:  [   uid_feature   feature_group    feature      label district  \
# 0            1  Cultural Lines  Fenceline  New Fence    Roper
# 1            1  Cultural Lines  Fenceline  New Fence    Roper
# 2            1  Cultural Lines  Fenceline  New Fence    Roper
#
#           property prop_code    date_rec  date_curr  \
# 0  MOUNTAIN VALLEY       MTV  2021-06-19        NaN
# 1  MOUNTAIN VALLEY       MTV  2021-06-19        NaN
# 2  MOUNTAIN VALLEY       MTV  2021-06-19        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 2  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat         lon    acc  dist     bear
# 0 -14.309840  133.809343  4.551   NaN      NaN
# 1 -14.305940  133.809473  4.551   0.0    0.000
# 2 -14.305819  133.807986  4.551  30.0  272.306  ,    uid_feature   feature_group       feature      label district  \
# 0            2  Cultural Lines  Cleared Line  New Track    Roper
# 1            2  Cultural Lines  Cleared Line  New Track    Roper
#
#           property prop_code    date_rec  date_curr  \
# 0  MOUNTAIN VALLEY       MTV  2021-06-19        NaN
# 1  MOUNTAIN VALLEY       MTV  2021-06-19        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat         lon    acc  dist  bear
# 0 -14.276329  133.809207  5.364   NaN   NaN
# 1 -14.275248  133.804859  4.984   0.0   0.0  ]
#  - point feature:  infra_water_points
#  - point feature:  clearing
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  feral_animals
#  - point feature:  unidentified
# ==================================================
# property name to be processed:  MURRANJI
#  - point feature:  infra_points
#  - point feature:  infra_water_points
#  - point feature:  clearing
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  NAPPERBY
#  - point feature:  infra_water_points
#  - point feature:  erosion
# ==================================================
# property name to be processed:  NARWIETOOMA
#  - point feature:  infra_points
#  - point feature:  clearing
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  NEWRY
#  - point feature:  infra_points
#  - point feature:  infra_water_points
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  feral_animals
#  - point feature:  fire
# ==================================================
# property name to be processed:  OLD MOUNT BUNDEY
# df_list:  [   uid_feature   feature_group    feature          label district  \
# 0            1  Cultural Lines  Fenceline  New Fenceline   Darwin
# 1            1  Cultural Lines  Fenceline  New Fenceline   Darwin
#
#            property prop_code    date_rec  date_curr  \
# 0  OLD MOUNT BUNDEY       OMB  2021-08-11        NaN
# 1  OLD MOUNT BUNDEY       OMB  2021-08-11        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat         lon  acc  dist  bear
# 0 -12.926052  131.503769  6.0   NaN   NaN
# 1 -12.938845  131.508468  6.0   0.0   0.0  ]
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  feral_animals
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  OORATIPPRA
# df_list:  [   uid_feature   feature_group    feature         label district    property  \
# 0            1  Cultural Lines  Fenceline  Not Recorded   Plenty  OORATIPPRA
# 1            1  Cultural Lines  Fenceline  Not Recorded   Plenty  OORATIPPRA
#
#   prop_code    date_rec  date_curr                            source  \
# 0       OTP  2021-06-23        NaN  NTG Rangelands Monitoring Branch
# 1       OTP  2021-06-23        NaN  NTG Rangelands Monitoring Branch
#
#    length_m display       comment  datum        lat         lon    acc  dist  \
# 0         0     Yes  Not recorded  wgs84 -21.986246  136.216738  4.854   NaN
# 1         0     Yes  Not recorded  wgs84 -21.989339  136.217030  4.854   0.0
#
#    bear
# 0   NaN
# 1   0.0  ]
#  - point feature:  infra_water_points
#  - point feature:  erosion
#  - point feature:  fire
#  - point feature:  unidentified
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  PUNGALINA
#  - point feature:  weeds
#  - point feature:  feral_animals
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  RIVEREN
#  - point feature:  infra_water_points
# ==================================================
# property name to be processed:  ROCKHAMPTON DOWNS
# df_list:  [   uid_feature   feature_group    feature         label district  \
# 0            1  Cultural Lines  Fenceline  Not Recorded   Barkly
# 1            1  Cultural Lines  Fenceline  Not Recorded   Barkly
# 2            1  Cultural Lines  Fenceline  Not Recorded   Barkly
# 3            1  Cultural Lines  Fenceline  Not Recorded   Barkly
# 4            1  Cultural Lines  Fenceline  Not Recorded   Barkly
#
#             property prop_code    date_rec  date_curr  \
# 0  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 1  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 2  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 3  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 4  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 2  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 3  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 4  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat         lon    acc  dist  bear
# 0 -18.520950  135.035486  4.551   NaN   NaN
# 1 -18.517749  135.036249  4.551   0.0   0.0
# 2 -18.506033  135.036107  4.551   0.0   0.0
# 3 -18.469834  135.035662  4.551   0.0   0.0
# 4 -18.455969  135.035491  4.551   0.0   0.0  ,    uid_feature   feature_group    feature         label district  \
# 0            2  Cultural Lines  Fenceline  Not Recorded   Barkly
# 1            2  Cultural Lines  Fenceline  Not Recorded   Barkly
# 2            2  Cultural Lines  Fenceline  Not Recorded   Barkly
#
#             property prop_code    date_rec  date_curr  \
# 0  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 1  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 2  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 2  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat         lon     acc  dist  bear
# 0 -18.523376  135.034929   4.551   NaN   NaN
# 1 -18.536403  135.031833  13.653   0.0   0.0
# 2 -18.554960  135.027353   4.551   0.0   0.0  ,    uid_feature   feature_group    feature         label district  \
# 0            3  Cultural Lines  Fenceline  Not Recorded   Barkly
# 1            3  Cultural Lines  Fenceline  Not Recorded   Barkly
# 2            3  Cultural Lines  Fenceline  Not Recorded   Barkly
# 3            3  Cultural Lines  Fenceline  Not Recorded   Barkly
# 4            3  Cultural Lines  Fenceline  Not Recorded   Barkly
# 5            3  Cultural Lines  Fenceline  Not Recorded   Barkly
# 6            3  Cultural Lines  Fenceline  Not Recorded   Barkly
#
#             property prop_code    date_rec  date_curr  \
# 0  ROCKHAMPTON DOWNS       RHD  2021-05-20        NaN
# 1  ROCKHAMPTON DOWNS       RHD  2021-05-20        NaN
# 2  ROCKHAMPTON DOWNS       RHD  2021-05-20        NaN
# 3  ROCKHAMPTON DOWNS       RHD  2021-05-20        NaN
# 4  ROCKHAMPTON DOWNS       RHD  2021-05-20        NaN
# 5  ROCKHAMPTON DOWNS       RHD  2021-05-20        NaN
# 6  ROCKHAMPTON DOWNS       RHD  2021-05-20        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 2  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 3  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 4  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 5  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 6  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat         lon    acc  dist  bear
# 0 -18.942139  134.973043  4.551   NaN   NaN
# 1 -18.942413  134.975453  4.551   0.0   0.0
# 2 -18.942525  134.976136  4.551   0.0   0.0
# 3 -18.942669  134.976985  4.551   0.0   0.0
# 4 -18.943098  134.979573  4.551   0.0   0.0
# 5 -18.943368  134.981172  4.551   0.0   0.0
# 6 -18.943674  134.983140  4.551   0.0   0.0  ,    uid_feature   feature_group    feature         label district  \
# 0            4  Cultural Lines  Fenceline  Not Recorded   Barkly
# 1            4  Cultural Lines  Fenceline  Not Recorded   Barkly
#
#             property prop_code    date_rec  date_curr  \
# 0  ROCKHAMPTON DOWNS       RHD  2021-05-20        NaN
# 1  ROCKHAMPTON DOWNS       RHD  2021-05-20        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat         lon    acc  dist  bear
# 0 -18.942124  134.973749  4.551   NaN   NaN
# 1 -18.944307  134.988258  4.551   0.0   0.0  ,    uid_feature   feature_group    feature         label district  \
# 0            5  Cultural Lines  Fenceline  Not Recorded   Barkly
# 1            5  Cultural Lines  Fenceline  Not Recorded   Barkly
# 2            5  Cultural Lines  Fenceline  Not Recorded   Barkly
# 3            5  Cultural Lines  Fenceline  Not Recorded   Barkly
# 4            5  Cultural Lines  Fenceline  Not Recorded   Barkly
#
#             property prop_code    date_rec  date_curr  \
# 0  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 1  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 2  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 3  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 4  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 2  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 3  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 4  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat         lon    acc  dist  bear
# 0 -18.520942  135.035500  4.551   NaN   NaN
# 1 -18.517738  135.036269  4.551   0.0   0.0
# 2 -18.506011  135.036124  4.551   0.0   0.0
# 3 -18.469821  135.035668  4.551   0.0   0.0
# 4 -18.455949  135.035499  4.551   0.0   0.0  ,    uid_feature   feature_group    feature         label district  \
# 0            6  Cultural Lines  Fenceline  Not Recorded   Barkly
# 1            6  Cultural Lines  Fenceline  Not Recorded   Barkly
# 2            6  Cultural Lines  Fenceline  Not Recorded   Barkly
# 3            6  Cultural Lines  Fenceline  Not Recorded   Barkly
#
#             property prop_code    date_rec  date_curr  \
# 0  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 1  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 2  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
# 3  ROCKHAMPTON DOWNS       RHD  2021-05-21        NaN
#
#                              source  length_m display       comment  datum  \
# 0  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 1  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 2  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
# 3  NTG Rangelands Monitoring Branch         0     Yes  Not recorded  wgs84
#
#          lat         lon    acc  dist  bear
# 0 -18.523249  135.034994  4.551   NaN   NaN
# 1 -18.523349  135.034928  4.551   0.0   0.0
# 2 -18.535916  135.031931  4.551   0.0   0.0
# 3 -18.554975  135.027368  4.551   0.0   0.0  ]
#  - point feature:  infra_points
#  - point feature:  infra_water_points
#  - point feature:  weeds
#  - point feature:  unidentified
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  ROSEWOOD
#  - point feature:  infra_points
#  - point feature:  clearing
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  feral_animals
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  SEVEN EMU
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  feral_animals
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  SINGLETON
#  - point feature:  infra_water_points
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  SPIRIT HILLS
#  - point feature:  infra_water_points
# ==================================================
# property name to be processed:  SPRING CREEK
#  - point feature:  weeds
#  - point feature:  feral_animals
# ==================================================
# property name to be processed:  STIRLING
#  - point feature:  unidentified
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  THE GARDEN
#  - point feature:  erosion
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  TOBERMOREY
#  - point feature:  infra_water_points
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  WALHALLOW
#  - point feature:  infra_points
#  - point feature:  erosion
#  - point feature:  weeds
# ==================================================
# property name to be processed:  WALLAMUNGA
#  - point feature:  infra_points
#  - point feature:  infra_water_points
#  - point feature:  weeds
#  - point feature:  feral_animals
# ==================================================
# property name to be processed:  WELLTREE
# df_list:  [   uid_feature   feature_group    feature      label district  property  \
# 0            1  Cultural Lines  Fenceline  New Fence   Darwin  WELLTREE
# 1            1  Cultural Lines  Fenceline  New Fence   Darwin  WELLTREE
# 2            1  Cultural Lines  Fenceline  New Fence   Darwin  WELLTREE
#
#   prop_code    date_rec  date_curr                            source  \
# 0       WLT  2021-10-12        NaN  NTG Rangelands Monitoring Branch
# 1       WLT  2021-10-12        NaN  NTG Rangelands Monitoring Branch
# 2       WLT  2021-10-12        NaN  NTG Rangelands Monitoring Branch
#
#    length_m display       comment  datum        lat         lon  acc  dist  \
# 0         0     Yes  Not recorded  wgs84 -13.185994  130.635415  6.0   NaN
# 1         0     Yes  Not recorded  wgs84 -13.185994  130.635415  6.0   0.0
# 2         0     Yes  Not recorded  wgs84 -13.185994  130.635415  6.0   0.0
#
#    bear
# 0   NaN
# 1   0.0
# 2   0.0  ]
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  fire
# ==================================================
# property name to be processed:  WOODGREEN
#  - point feature:  infra_water_points
#  - point feature:  erosion
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  WOOLNER
#  - point feature:  infra_water_points
#  - point feature:  clearing
#  - point feature:  paddock
#  - point feature:  weeds
#  - point feature:  feral_animals
#  - point feature:  other_feature
# ==================================================
# property name to be processed:  UNKNOWN
#  - point feature:  infra_points
#  - point feature:  erosion
#  - point feature:  weeds
#  - point feature:  feral_animals
#  - point feature:  other_feature
# ==================================================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\DENR\code\rangeland_monitoring\rmb_mapping_pipeline\code\step1_1_initiate_mapping_pipeline.py in <module>()
#     453
#     454 if __name__ == "__main__":
# --> 455     main_routine()
#
# E:\DENR\code\rangeland_monitoring\rmb_mapping_pipeline\code\step1_1_initiate_mapping_pipeline.py in main_routine()
#     393                               primary_temp_dir, pastoral_estate, feature_list, primary_export_dir, start_date, end_date,
#     394                               pastoral_districts_path, weeds_bot_com, property_enquire, user_df,
# --> 395                               transition_dir, infrastructure_directory, assets_dir, remote_desktop)
#     396
#     397     print(primary_temp_dir, " has been deleted from your hard drive.")
#
# E:\DENR\code\rangeland_monitoring\rmb_mapping_pipeline\code\step1_1_initiate_mapping_pipeline.py in odk_export_csv_checker_fn(dir_path, search_criteria, primary_temp_dir, pastoral_estate, feature_list, primary_export_dir, start_date, end_date, pastoral_districts_path, weeds_bot_com, property_enquire, user_df, transition_dir, infrastructure_directory, assets_dir, remote_desktop)
#     222                                                          pastoral_districts_path, weeds_bot_com, property_enquire,
#     223                                                          user_df, transition_dir, infrastructure_directory, assets_dir,
# --> 224                                                          remote_desktop)
#     225
#     226     return property_processed_list
#
# E:\DENR\code\rangeland_monitoring\rmb_mapping_pipeline\code\step2_1_mapping_processing_workflow.py in main_routine(file_path, primary_temp_dir, pastoral_estate, feature_list, primary_export_dir, start_date, end_date, pastoral_districts_path, weeds_bot_com, prop_enquire, user_df, transition_dir, infrastructure_directory, assets_dir, remote_desktop)
#     720
#     721         import step5_1_file_outputs_to_working_drive
# --> 722         step5_1_file_outputs_to_working_drive.main_routine(primary_export_dir, pastoral_districts_path, start_date)
#     723
#     724         import step6_1_download_adjacent_infrastructure
#
# E:\DENR\code\rangeland_monitoring\rmb_mapping_pipeline\code\step5_1_file_outputs_to_working_drive.py in main_routine(output_dir, path, start_date)
#     553
#     554             #print('destination_dir: ', destination_dir)
# --> 555             destination_year = os.path.join(destination_dir, 'Infrastructure', 'Field_Data', year)
#     556             #print('destination_year: ', destination_year)
#     557
#
# C:\ProgramData\Miniconda3\envs\rmb_zonal\lib\ntpath.py in join(path, *paths)
#      74 # Join two (or more) paths.
#      75 def join(path, *paths):
# ---> 76     path = os.fspath(path)
#      77     if isinstance(path, bytes):
#      78         sep = b'\\'
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType
